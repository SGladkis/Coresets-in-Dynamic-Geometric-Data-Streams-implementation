# %%
import numpy as np
import sklearn as sk
from sklearn import datasets
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from sklearn.cluster import KMeans
from sklearn import metrics
import math
from yellowbrick.cluster import SilhouetteVisualizer

# %%
n = 1000

# %%
blobs, blob_labels = sk.datasets.make_blobs(n_samples=n, n_features=2, center_box=(0, 10.0), centers=2, cluster_std=0.5, random_state=1)
blobs = blobs.round(3)
plt.scatter(blobs[:, 0], blobs[:, 1], c=blob_labels, cmap="bwr", s=2)
plt.grid(which='major');

# %%
k = 2
d = 2 #0.00005 #0.000005 #0.0000005
eps = 0.1
X = blobs
n_initial = len(X) # the size of the current point set, a.k.a. n is all of the initial points

# %%
def visualize_splitting(Z, c_centers, lines, X, initial_bbox, title="Sub-Cell Construction"):
    plt.figure(figsize=(8, 6))

    # Plot the initial bounding box
    bbox = np.array(initial_bbox)
    plt.plot(bbox[:, 0], bbox[:, 1], color='green', linestyle='-', linewidth=1) #label='Initial Bounding Box'

    # Plot the original points
    #plt.scatter(X[:, 0], X[:, 1], color='blue', marker='.', label='Original Points')

    # Plot cell centers
    centers = np.array(c_centers)
   # plt.scatter(centers[:, 0], centers[:, 1], color='red', marker='x', label='Cell Centers', s=45)

    # Plot the splitting lines
    for line in lines:
        for rect_coords in line:
            rect = patches.Rectangle(
                (rect_coords[0][0], rect_coords[1][0]),  # Bottom-left and top-right corner
                rect_coords[0][1] - rect_coords[0][0],   # Width
                rect_coords[1][1] - rect_coords[1][0],   # Height
                edgecolor='green', facecolor='none')
            plt.gca().add_patch(rect)

    plt.title(title)
    plt.axis("off")
    plt.legend(loc='upper left', bbox_to_anchor=(0.03, 1.08), frameon=True, framealpha=1, edgecolor='black')
    plt.grid(False)
    plt.show()

# %%
def recursive_split(X, cell, k, d, eps, opt, n_initial, delta, nr_of_cells, cs, i, lines, Z, c_centers):
    x1, x2, y1, y2 = cell
    points_in_cell = X[(X[:, 0] >= x1) & (X[:, 0] <= x2) & (X[:, 1] >= y1) & (X[:, 1] <= y2)]
    
    threshold = ((delta)*opt) / pow(2, i)
    print("Threshold value:", round(threshold, 5), "Points in cell:", len(points_in_cell))
    if len(points_in_cell) < threshold:
        # If there are less than the threshold number of points, it's a light cell
        # First time this is checked, it checks the grid g**i if it is light (step #3)
        # Afterwards when it recurs it does step #3.4, marks c as a light cell and adds it to Z
        # Also when it recurs it does step #3.5 here (delete c from Y) as the light cell c will no longer be recured
        
        if len(points_in_cell) >= 1: 
            #print("\033[1m Points in light cell:\n", points_in_cell, "\033[0;0m")
            # If c is not empty (this already checks step #4)
            Z.append(points_in_cell)
            # Save the center coordinates for step #4.1
            c_centers.append(((x1 + x2) / 2, (y1 + y2) / 2))
    else: 
        #print("Current number of cells: " + str(nr_of_cells))
        # Cell counter, each time a cell gets split into 4 subcells the total increases by 3
        nr_of_cells = nr_of_cells + 3

        # The would-be number of cells if the below code executes
        # Does not allow to create more subcells than cs
        if i>=0 and len(points_in_cell)!=0:# and i >= np.log(delta * opt)+1: # and nr_of_cells <= cs:
        
            # Step #3.1 if c is heavy then: Split the cell
            # First time this executes - only if g**i is heavy and splits it into 4 sub-cells c1, c2, c3, c4 (step #3)
            # Afterwards the level of each cell goes to g**i-1, with side length 2**i-1 with each recursion
            i = i - 1
            mid_x = (x1 + x2) / 2
            mid_y = (y1 + y2) / 2
            
            lines.append([
                ((x1, mid_x), (y1, mid_y)),  # Top-left
                ((mid_x, x2), (y1, mid_y)),  # Top-right
                ((x1, mid_x), (mid_y, y2)),  # Bottom-left
                ((mid_x, x2), (mid_y, y2))])  # Bottom-right
            
            cells = [
                (x1, mid_x, y1, mid_y),  # Top-left
                (mid_x, x2, y1, mid_y),  # Top-right
                (x1, mid_x, mid_y, y2),  # Bottom-left
                (mid_x, x2, mid_y, y2)   # Bottom-right
            ]
            # Step #3.2 and #3.3 as it implicitly adds c1, c2, c3, c4 to Y with each recursion below
            for sub_cell in cells:
                recursive_split(points_in_cell, sub_cell, k, d, eps, opt, n_initial, delta, nr_of_cells, cs, i, lines,
                                Z, c_centers)
    return Z, c_centers, lines

# %%
def coreset(Z, rep_c, delta, cs, eps):
    
    # rep_c = c_centers = representative center point of a cell
    # n_c = number of  points in each cell
    n_c = [len(c) for c in Z]
    
    # S = pairs respective center coordinates with number of points in each cell
    S = []
    for index in range(0, len(rep_c)):
        S.append([rep_c[index], n_c[index]])
    #print(rep_c, n_c)
    if len(S) > cs*(1+eps) or len(S) == 0:
        return None # failure indication
    else:
        return S

# %%
def coreset_construction(X, k, d, eps, n_initial):
    
    if X.size > 0: 
        print("The array is non-empty, proceeding with coreset construction algorithm")
        
        # Step #1: Define the boundaries of the coordinate plane, at the start let Y be the only cell in grid g^(log(D))
        x_min, x_max, y_min, y_max = min(X[:, 0]), max(X[:, 0]), min(X[:, 1]), max(X[:, 1])
        Y = x_min, x_max, y_min, y_max
        
        # Calculate delta
        #delta below 6 fails to construct coreset
        delta = ( 1 / ( (4*k*np.sqrt(d)) * (np.log(n_initial)+1) ) )
        if delta < 1: delta = 6
        #delta = ( 1 / ( (4*k*np.sqrt(d)) * (np.log(n_initial)+1) ) ) * pow( ( eps / (14*np.sqrt(d)) ), d)
        print("delta =", round(delta, 4))
        # Calculate coreset size
        cs = math.ceil(2/delta + (np.log(n_initial) + 2) * k * pow(2, d))
        print("cs =", cs)
        DELTA = 6 # take DELTA as an arbitrary constant, lets say 5
        # Opt = number of guesses for opt approx., round up: log_base(1 + eps)(DELTA * n * sqrt(d))
        Opt =  math.ceil((np.log(n_initial*6*np.sqrt(d))/np.log(1 + eps)))
        print("Number of guesses for opt approximation =", Opt)

        for j in range(0, Opt):
            print("\nIteration j = " + str(j) + ", with approximation Opt = (1+eps)^j = " + str(pow((1+eps), j)) + "\n")
            
            # Cell counter
            nr_of_cells = 1
            # i-th iteration tracking for recursive alg
            i = DELTA
            # Lines defining sub-cell boundries
            lines = []
            # Step #0: arr to store light cells c
            Z = []
            # Cell centers
            c_centers = []

            # Start the recursive splitting, here Opt = (1+eps)^j
            Z, c_centers, lines = recursive_split(X, Y, k, d, eps, pow((1+eps), j), n_initial,
                                                  delta, nr_of_cells, cs, i, lines, Z, c_centers)
            # Start the coreset calculation
            S = coreset(Z, c_centers, delta, cs, eps)
                        
            if S is not None:
                print("\n Coreset constructed: \n", S, ", of size:", len(S))
                
                initial_bbox = [[x_min, y_min], [x_max, y_min], [x_max, y_max], [x_min, y_max], [x_min, y_min]]
                visualize_splitting(Z, c_centers, lines, X, initial_bbox)
                
                return S
        return "Coreset could not be constructed"
    else:
        return "The array is empty."

# %%
S = coreset_construction(X, k, d, eps, n_initial)
# Out:
# The array is non-empty, proceeding with coreset construction algorithm
# delta = 6
# cs = 72
# Number of guesses for opt approximation = 94
#
# Iteration j = 0, with approximation Opt = (1+eps)^j = 1.0
#
# Threshold value: 0.09375 Points in cell: 1000
# Threshold value: 0.1875 Points in cell: 500
# Threshold value: 0.375 Points in cell: 287
# Threshold value: 0.75 Points in cell: 8
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 37
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 0.75 Points in cell: 53
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 20
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 10
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 6
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 0
# Threshold value: 12.0 Points in cell: 2
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 19
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 11
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 0.75 Points in cell: 189
# Threshold value: 1.5 Points in cell: 44
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 16
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 13
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 1.5 Points in cell: 42
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 17
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 6
# Threshold value: 12.0 Points in cell: 0
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 12
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 8
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 2
# Threshold value: 12.0 Points in cell: 2
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 46
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 13
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 6
# Threshold value: 12.0 Points in cell: 0
# Threshold value: 12.0 Points in cell: 4
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 12
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 13
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 1.5 Points in cell: 57
# Threshold value: 3.0 Points in cell: 17
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 6
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 3.0 Points in cell: 19
# Threshold value: 6.0 Points in cell: 8
# Threshold value: 12.0 Points in cell: 4
# Threshold value: 12.0 Points in cell: 0
# Threshold value: 12.0 Points in cell: 2
# Threshold value: 12.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 14
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 0.375 Points in cell: 87
# Threshold value: 0.75 Points in cell: 13
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 73
# Threshold value: 1.5 Points in cell: 23
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 38
# Threshold value: 3.0 Points in cell: 12
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 13
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.375 Points in cell: 96
# Threshold value: 0.75 Points in cell: 24
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 17
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 69
# Threshold value: 1.5 Points in cell: 27
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 12
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 26
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 3
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.375 Points in cell: 30
# Threshold value: 0.75 Points in cell: 30
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.1875 Points in cell: 0
# Threshold value: 0.1875 Points in cell: 0
# Threshold value: 0.1875 Points in cell: 500
# Threshold value: 0.375 Points in cell: 89
# Threshold value: 0.75 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 4
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 7
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 77
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 14
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 1.5 Points in cell: 47
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 3.0 Points in cell: 11
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 12
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 15
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 0.375 Points in cell: 183
# Threshold value: 0.75 Points in cell: 12
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 154
# Threshold value: 1.5 Points in cell: 27
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 10
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 69
# Threshold value: 3.0 Points in cell: 16
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 11
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 21
# Threshold value: 6.0 Points in cell: 7
# Threshold value: 12.0 Points in cell: 0
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 7
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 12.0 Points in cell: 2
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 21
# Threshold value: 6.0 Points in cell: 6
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 6
# Threshold value: 12.0 Points in cell: 2
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 12.0 Points in cell: 0
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 1.5 Points in cell: 45
# Threshold value: 3.0 Points in cell: 16
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 7
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 12.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 14
# Threshold value: 6.0 Points in cell: 6
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 12.0 Points in cell: 2
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 16
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.375 Points in cell: 82
# Threshold value: 0.75 Points in cell: 2
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 77
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 39
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 12
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 3
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.375 Points in cell: 146
# Threshold value: 0.75 Points in cell: 127
# Threshold value: 1.5 Points in cell: 59
# Threshold value: 3.0 Points in cell: 14
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 11
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 17
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 17
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 1.5 Points in cell: 32
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 13
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 24
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 12
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 13
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 6
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
#
# Iteration j = 1, with approximation Opt = (1+eps)^j = 1.1
#
# Threshold value: 0.10313 Points in cell: 1000
# Threshold value: 0.20625 Points in cell: 500
# Threshold value: 0.4125 Points in cell: 287
# Threshold value: 0.825 Points in cell: 8
# Threshold value: 1.65 Points in cell: 0
# Threshold value: 1.65 Points in cell: 0
# Threshold value: 1.65 Points in cell: 1
# Threshold value: 1.65 Points in cell: 7
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 3
# Threshold value: 0.825 Points in cell: 37
# Threshold value: 1.65 Points in cell: 4
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 1.65 Points in cell: 0
# Threshold value: 1.65 Points in cell: 15
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 5
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 3.3 Points in cell: 8
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 1.65 Points in cell: 18
# Threshold value: 3.3 Points in cell: 5
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 3
# Threshold value: 3.3 Points in cell: 9
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 0.825 Points in cell: 53
# Threshold value: 1.65 Points in cell: 6
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 4
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 1.65 Points in cell: 20
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 7
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 10
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 6
# Threshold value: 1.65 Points in cell: 8
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 3
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 4
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 1.65 Points in cell: 19
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 4
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 11
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 0.825 Points in cell: 189
# Threshold value: 1.65 Points in cell: 44
# Threshold value: 3.3 Points in cell: 8
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 3.3 Points in cell: 7
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 3.3 Points in cell: 16
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 3.3 Points in cell: 13
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 1.65 Points in cell: 42
# Threshold value: 3.3 Points in cell: 9
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 3.3 Points in cell: 4
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 3.3 Points in cell: 17
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 6.6 Points in cell: 6
# Threshold value: 3.3 Points in cell: 12
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 8
# Threshold value: 13.2 Points in cell: 1
# Threshold value: 13.2 Points in cell: 2
# Threshold value: 13.2 Points in cell: 2
# Threshold value: 13.2 Points in cell: 3
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 1.65 Points in cell: 46
# Threshold value: 3.3 Points in cell: 8
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 3.3 Points in cell: 13
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 6
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 3.3 Points in cell: 12
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 3.3 Points in cell: 13
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 1.65 Points in cell: 57
# Threshold value: 3.3 Points in cell: 17
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 6
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 3.3 Points in cell: 19
# Threshold value: 6.6 Points in cell: 8
# Threshold value: 13.2 Points in cell: 4
# Threshold value: 13.2 Points in cell: 0
# Threshold value: 13.2 Points in cell: 2
# Threshold value: 13.2 Points in cell: 2
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 3.3 Points in cell: 14
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 3.3 Points in cell: 7
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 0.4125 Points in cell: 87
# Threshold value: 0.825 Points in cell: 13
# Threshold value: 1.65 Points in cell: 4
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 1.65 Points in cell: 0
# Threshold value: 1.65 Points in cell: 6
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 3
# Threshold value: 1.65 Points in cell: 3
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 3
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 0.825 Points in cell: 0
# Threshold value: 0.825 Points in cell: 73
# Threshold value: 1.65 Points in cell: 23
# Threshold value: 3.3 Points in cell: 5
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 3.3 Points in cell: 4
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 3.3 Points in cell: 6
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 3.3 Points in cell: 8
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 1.65 Points in cell: 6
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 3
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 1.65 Points in cell: 38
# Threshold value: 3.3 Points in cell: 12
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 3.3 Points in cell: 13
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 3.3 Points in cell: 7
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 3.3 Points in cell: 6
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 1.65 Points in cell: 6
# Threshold value: 3.3 Points in cell: 3
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 0.825 Points in cell: 1
# Threshold value: 1.65 Points in cell: 1
# Threshold value: 1.65 Points in cell: 0
# Threshold value: 1.65 Points in cell: 0
# Threshold value: 1.65 Points in cell: 0
# Threshold value: 0.4125 Points in cell: 96
# Threshold value: 0.825 Points in cell: 24
# Threshold value: 1.65 Points in cell: 3
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 1.65 Points in cell: 17
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 8
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 5
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 1.65 Points in cell: 1
# Threshold value: 1.65 Points in cell: 3
# Threshold value: 3.3 Points in cell: 2
# Threshold value: 3.3 Points in cell: 1
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 3.3 Points in cell: 0
# Threshold value: 0.825 Points in cell: 69
# Threshold value: 1.65 Points in cell: 27
# Threshold value: 3.3 Points in cell: 9
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 3.3 Points in cell: 12
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 5
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 3.3 Points in cell: 3
# Threshold value: 3.3 Points in cell: 3
# Threshold value: 1.65 Points in cell: 26
# Threshold value: 3.3 Points in cell: 6
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 3.3 Points in cell: 7
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 3.3 Points in cell: 4
# Threshold value: 6.6 Points in cell: 2
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 0
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 3.3 Points in cell: 9
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 6.6 Points in cell: 4
# Threshold value: 6.6 Points in cell: 3
# Threshold value: 6.6 Points in cell: 1
# Threshold value: 1.65 Points in cell: 8
# ...
# Threshold value: 34.83773 Points in cell: 11
# Threshold value: 34.83773 Points in cell: 47
# Threshold value: 69.67546 Points in cell: 9
# Threshold value: 69.67546 Points in cell: 11
# Threshold value: 69.67546 Points in cell: 12
# Threshold value: 69.67546 Points in cell: 15
# Threshold value: 8.70943 Points in cell: 183
# Threshold value: 17.41887 Points in cell: 12
# Threshold value: 17.41887 Points in cell: 1
# Threshold value: 17.41887 Points in cell: 154
# Threshold value: 34.83773 Points in cell: 27
# Threshold value: 34.83773 Points in cell: 13
# Threshold value: 34.83773 Points in cell: 69
# Threshold value: 69.67546 Points in cell: 16
# Threshold value: 69.67546 Points in cell: 11
# Threshold value: 69.67546 Points in cell: 21
# Threshold value: 69.67546 Points in cell: 21
# Threshold value: 34.83773 Points in cell: 45
# Threshold value: 69.67546 Points in cell: 16
# Threshold value: 69.67546 Points in cell: 7
# Threshold value: 69.67546 Points in cell: 14
# Threshold value: 69.67546 Points in cell: 8
# Threshold value: 17.41887 Points in cell: 16
# Threshold value: 8.70943 Points in cell: 82
# Threshold value: 17.41887 Points in cell: 2
# Threshold value: 17.41887 Points in cell: 77
# Threshold value: 34.83773 Points in cell: 15
# Threshold value: 34.83773 Points in cell: 39
# Threshold value: 69.67546 Points in cell: 9
# Threshold value: 69.67546 Points in cell: 12
# Threshold value: 69.67546 Points in cell: 9
# Threshold value: 69.67546 Points in cell: 9
# Threshold value: 34.83773 Points in cell: 5
# Threshold value: 34.83773 Points in cell: 18
# Threshold value: 17.41887 Points in cell: 0
# Threshold value: 17.41887 Points in cell: 3
# Threshold value: 8.70943 Points in cell: 146
# Threshold value: 17.41887 Points in cell: 127
# Threshold value: 34.83773 Points in cell: 59
# Threshold value: 69.67546 Points in cell: 14
# Threshold value: 69.67546 Points in cell: 11
# Threshold value: 69.67546 Points in cell: 17
# Threshold value: 69.67546 Points in cell: 17
# Threshold value: 34.83773 Points in cell: 32
# Threshold value: 34.83773 Points in cell: 24
# Threshold value: 34.83773 Points in cell: 12
# Threshold value: 17.41887 Points in cell: 13
# Threshold value: 17.41887 Points in cell: 6
# Threshold value: 17.41887 Points in cell: 0
#
# Iteration j = 34, with approximation Opt = (1+eps)^j = 25.54766986187666
#
# Threshold value: 2.39509 Points in cell: 1000
# Threshold value: 4.79019 Points in cell: 500
# Threshold value: 9.58038 Points in cell: 287
# Threshold value: 19.16075 Points in cell: 8
# Threshold value: 19.16075 Points in cell: 37
# Threshold value: 38.3215 Points in cell: 4
# Threshold value: 38.3215 Points in cell: 0
# Threshold value: 38.3215 Points in cell: 15
# Threshold value: 38.3215 Points in cell: 18
# Threshold value: 19.16075 Points in cell: 53
# Threshold value: 38.3215 Points in cell: 6
# Threshold value: 38.3215 Points in cell: 20
# Threshold value: 38.3215 Points in cell: 8
# Threshold value: 38.3215 Points in cell: 19
# Threshold value: 19.16075 Points in cell: 189
# Threshold value: 38.3215 Points in cell: 44
# Threshold value: 76.64301 Points in cell: 8
# Threshold value: 76.64301 Points in cell: 7
# Threshold value: 76.64301 Points in cell: 16
# Threshold value: 76.64301 Points in cell: 13
# Threshold value: 38.3215 Points in cell: 42
# Threshold value: 76.64301 Points in cell: 9
# Threshold value: 76.64301 Points in cell: 4
# Threshold value: 76.64301 Points in cell: 17
# Threshold value: 76.64301 Points in cell: 12
# Threshold value: 38.3215 Points in cell: 46
# Threshold value: 76.64301 Points in cell: 8
# Threshold value: 76.64301 Points in cell: 13
# Threshold value: 76.64301 Points in cell: 12
# Threshold value: 76.64301 Points in cell: 13
# Threshold value: 38.3215 Points in cell: 57
# Threshold value: 76.64301 Points in cell: 17
# Threshold value: 76.64301 Points in cell: 19
# Threshold value: 76.64301 Points in cell: 14
# Threshold value: 76.64301 Points in cell: 7
# Threshold value: 9.58038 Points in cell: 87
# Threshold value: 19.16075 Points in cell: 13
# Threshold value: 19.16075 Points in cell: 0
# Threshold value: 19.16075 Points in cell: 73
# Threshold value: 38.3215 Points in cell: 23
# Threshold value: 38.3215 Points in cell: 6
# Threshold value: 38.3215 Points in cell: 38
# Threshold value: 38.3215 Points in cell: 6
# Threshold value: 19.16075 Points in cell: 1
# Threshold value: 9.58038 Points in cell: 96
# Threshold value: 19.16075 Points in cell: 24
# Threshold value: 38.3215 Points in cell: 3
# Threshold value: 38.3215 Points in cell: 17
# Threshold value: 38.3215 Points in cell: 1
# Threshold value: 38.3215 Points in cell: 3
# Threshold value: 19.16075 Points in cell: 69
# Threshold value: 38.3215 Points in cell: 27
# Threshold value: 38.3215 Points in cell: 26
# Threshold value: 38.3215 Points in cell: 8
# Threshold value: 38.3215 Points in cell: 8
# Threshold value: 19.16075 Points in cell: 0
# Threshold value: 19.16075 Points in cell: 3
# Threshold value: 9.58038 Points in cell: 30
# Threshold value: 19.16075 Points in cell: 30
# Threshold value: 38.3215 Points in cell: 18
# Threshold value: 38.3215 Points in cell: 7
# Threshold value: 38.3215 Points in cell: 4
# Threshold value: 38.3215 Points in cell: 1
# Threshold value: 19.16075 Points in cell: 0
# Threshold value: 19.16075 Points in cell: 0
# Threshold value: 19.16075 Points in cell: 0
# Threshold value: 4.79019 Points in cell: 0
# Threshold value: 4.79019 Points in cell: 0
# Threshold value: 4.79019 Points in cell: 500
# Threshold value: 9.58038 Points in cell: 89
# Threshold value: 19.16075 Points in cell: 1
# Threshold value: 19.16075 Points in cell: 4
# Threshold value: 19.16075 Points in cell: 7
# Threshold value: 19.16075 Points in cell: 77
# Threshold value: 38.3215 Points in cell: 5
# Threshold value: 38.3215 Points in cell: 14
# Threshold value: 38.3215 Points in cell: 11
# Threshold value: 38.3215 Points in cell: 47
# Threshold value: 76.64301 Points in cell: 9
# Threshold value: 76.64301 Points in cell: 11
# Threshold value: 76.64301 Points in cell: 12
# Threshold value: 76.64301 Points in cell: 15
# Threshold value: 9.58038 Points in cell: 183
# Threshold value: 19.16075 Points in cell: 12
# Threshold value: 19.16075 Points in cell: 1
# Threshold value: 19.16075 Points in cell: 154
# Threshold value: 38.3215 Points in cell: 27
# Threshold value: 38.3215 Points in cell: 13
# Threshold value: 38.3215 Points in cell: 69
# Threshold value: 76.64301 Points in cell: 16
# Threshold value: 76.64301 Points in cell: 11
# Threshold value: 76.64301 Points in cell: 21
# Threshold value: 76.64301 Points in cell: 21
# Threshold value: 38.3215 Points in cell: 45
# Threshold value: 76.64301 Points in cell: 16
# Threshold value: 76.64301 Points in cell: 7
# Threshold value: 76.64301 Points in cell: 14
# Threshold value: 76.64301 Points in cell: 8
# Threshold value: 19.16075 Points in cell: 16
# Threshold value: 9.58038 Points in cell: 82
# Threshold value: 19.16075 Points in cell: 2
# Threshold value: 19.16075 Points in cell: 77
# Threshold value: 38.3215 Points in cell: 15
# Threshold value: 38.3215 Points in cell: 39
# Threshold value: 76.64301 Points in cell: 9
# Threshold value: 76.64301 Points in cell: 12
# Threshold value: 76.64301 Points in cell: 9
# Threshold value: 76.64301 Points in cell: 9
# Threshold value: 38.3215 Points in cell: 5
# Threshold value: 38.3215 Points in cell: 18
# Threshold value: 19.16075 Points in cell: 0
# Threshold value: 19.16075 Points in cell: 3
# Threshold value: 9.58038 Points in cell: 146
# Threshold value: 19.16075 Points in cell: 127
# Threshold value: 38.3215 Points in cell: 59
# Threshold value: 76.64301 Points in cell: 14
# Threshold value: 76.64301 Points in cell: 11
# Threshold value: 76.64301 Points in cell: 17
# Threshold value: 76.64301 Points in cell: 17
# Threshold value: 38.3215 Points in cell: 32
# Threshold value: 38.3215 Points in cell: 24
# Threshold value: 38.3215 Points in cell: 12
# Threshold value: 19.16075 Points in cell: 13
# Threshold value: 19.16075 Points in cell: 6
# Threshold value: 19.16075 Points in cell: 0
#
# Iteration j = 35, with approximation Opt = (1+eps)^j = 28.10243684806433
#
# Threshold value: 2.6346 Points in cell: 1000
# Threshold value: 5.26921 Points in cell: 500
# Threshold value: 10.53841 Points in cell: 287
# Threshold value: 21.07683 Points in cell: 8
# Threshold value: 21.07683 Points in cell: 37
# Threshold value: 42.15366 Points in cell: 4
# Threshold value: 42.15366 Points in cell: 0
# Threshold value: 42.15366 Points in cell: 15
# Threshold value: 42.15366 Points in cell: 18
# Threshold value: 21.07683 Points in cell: 53
# Threshold value: 42.15366 Points in cell: 6
# Threshold value: 42.15366 Points in cell: 20
# Threshold value: 42.15366 Points in cell: 8
# Threshold value: 42.15366 Points in cell: 19
# Threshold value: 21.07683 Points in cell: 189
# Threshold value: 42.15366 Points in cell: 44
# Threshold value: 84.30731 Points in cell: 8
# Threshold value: 84.30731 Points in cell: 7
# Threshold value: 84.30731 Points in cell: 16
# Threshold value: 84.30731 Points in cell: 13
# Threshold value: 42.15366 Points in cell: 42
# Threshold value: 42.15366 Points in cell: 46
# Threshold value: 84.30731 Points in cell: 8
# Threshold value: 84.30731 Points in cell: 13
# Threshold value: 84.30731 Points in cell: 12
# Threshold value: 84.30731 Points in cell: 13
# Threshold value: 42.15366 Points in cell: 57
# Threshold value: 84.30731 Points in cell: 17
# Threshold value: 84.30731 Points in cell: 19
# Threshold value: 84.30731 Points in cell: 14
# Threshold value: 84.30731 Points in cell: 7
# Threshold value: 10.53841 Points in cell: 87
# Threshold value: 21.07683 Points in cell: 13
# Threshold value: 21.07683 Points in cell: 0
# Threshold value: 21.07683 Points in cell: 73
# Threshold value: 42.15366 Points in cell: 23
# Threshold value: 42.15366 Points in cell: 6
# Threshold value: 42.15366 Points in cell: 38
# Threshold value: 42.15366 Points in cell: 6
# Threshold value: 21.07683 Points in cell: 1
# Threshold value: 10.53841 Points in cell: 96
# Threshold value: 21.07683 Points in cell: 24
# Threshold value: 42.15366 Points in cell: 3
# Threshold value: 42.15366 Points in cell: 17
# Threshold value: 42.15366 Points in cell: 1
# Threshold value: 42.15366 Points in cell: 3
# Threshold value: 21.07683 Points in cell: 69
# Threshold value: 42.15366 Points in cell: 27
# Threshold value: 42.15366 Points in cell: 26
# Threshold value: 42.15366 Points in cell: 8
# Threshold value: 42.15366 Points in cell: 8
# Threshold value: 21.07683 Points in cell: 0
# Threshold value: 21.07683 Points in cell: 3
# Threshold value: 10.53841 Points in cell: 30
# Threshold value: 21.07683 Points in cell: 30
# Threshold value: 42.15366 Points in cell: 18
# Threshold value: 42.15366 Points in cell: 7
# Threshold value: 42.15366 Points in cell: 4
# Threshold value: 42.15366 Points in cell: 1
# Threshold value: 21.07683 Points in cell: 0
# Threshold value: 21.07683 Points in cell: 0
# Threshold value: 21.07683 Points in cell: 0
# Threshold value: 5.26921 Points in cell: 0
# Threshold value: 5.26921 Points in cell: 0
# Threshold value: 5.26921 Points in cell: 500
# Threshold value: 10.53841 Points in cell: 89
# Threshold value: 21.07683 Points in cell: 1
# Threshold value: 21.07683 Points in cell: 4
# Threshold value: 21.07683 Points in cell: 7
# Threshold value: 21.07683 Points in cell: 77
# Threshold value: 42.15366 Points in cell: 5
# Threshold value: 42.15366 Points in cell: 14
# Threshold value: 42.15366 Points in cell: 11
# Threshold value: 42.15366 Points in cell: 47
# Threshold value: 84.30731 Points in cell: 9
# Threshold value: 84.30731 Points in cell: 11
# Threshold value: 84.30731 Points in cell: 12
# Threshold value: 84.30731 Points in cell: 15
# Threshold value: 10.53841 Points in cell: 183
# Threshold value: 21.07683 Points in cell: 12
# Threshold value: 21.07683 Points in cell: 1
# Threshold value: 21.07683 Points in cell: 154
# Threshold value: 42.15366 Points in cell: 27
# Threshold value: 42.15366 Points in cell: 13
# Threshold value: 42.15366 Points in cell: 69
# Threshold value: 84.30731 Points in cell: 16
# Threshold value: 84.30731 Points in cell: 11
# Threshold value: 84.30731 Points in cell: 21
# Threshold value: 84.30731 Points in cell: 21
# Threshold value: 42.15366 Points in cell: 45
# Threshold value: 84.30731 Points in cell: 16
# Threshold value: 84.30731 Points in cell: 7
# Threshold value: 84.30731 Points in cell: 14
# Threshold value: 84.30731 Points in cell: 8
# Threshold value: 21.07683 Points in cell: 16
# Threshold value: 10.53841 Points in cell: 82
# Threshold value: 21.07683 Points in cell: 2
# Threshold value: 21.07683 Points in cell: 77
# Threshold value: 42.15366 Points in cell: 15
# Threshold value: 42.15366 Points in cell: 39
# Threshold value: 42.15366 Points in cell: 5
# Threshold value: 42.15366 Points in cell: 18
# Threshold value: 21.07683 Points in cell: 0
# Threshold value: 21.07683 Points in cell: 3
# Threshold value: 10.53841 Points in cell: 146
# Threshold value: 21.07683 Points in cell: 127
# Threshold value: 42.15366 Points in cell: 59
# Threshold value: 84.30731 Points in cell: 14
# Threshold value: 84.30731 Points in cell: 11
# Threshold value: 84.30731 Points in cell: 17
# Threshold value: 84.30731 Points in cell: 17
# Threshold value: 42.15366 Points in cell: 32
# Threshold value: 42.15366 Points in cell: 24
# Threshold value: 42.15366 Points in cell: 12
# Threshold value: 21.07683 Points in cell: 13
# Threshold value: 21.07683 Points in cell: 6
# Threshold value: 21.07683 Points in cell: 0
#
#  Coreset constructed:
#  [[(-0.9433750000000001, 1.9304999999999999), 8], [(-0.26593750000000005, 1.68875), 4], [(-0.26593750000000005, 2.17225), 15], [(0.18568749999999998, 2.17225), 18], [(-1.1691875, 2.65575), 6], [(-0.7175625000000001, 2.65575), 20], [(-1.1691875, 3.1392499999999997), 8], [(-0.7175625000000001, 3.1392499999999997), 19], [(-0.37884375000000003, 2.5348749999999995), 8], [(-0.15303125000000004, 2.5348749999999995), 7], [(-0.37884375000000003, 2.776625), 16], [(-0.15303125000000004, 2.776625), 13], [(0.18568749999999998, 2.65575), 42], [(-0.37884375000000003, 3.018375), 8], [(-0.15303125000000004, 3.018375), 13], [(-0.37884375000000003, 3.2601249999999995), 12], [(-0.15303125000000004, 3.2601249999999995), 13], [(0.07278124999999998, 3.018375), 17], [(0.29859375, 3.018375), 19], [(0.07278124999999998, 3.2601249999999995), 14], [(0.29859375, 3.2601249999999995), 7], [(0.863125, 1.9304999999999999), 13], [(0.6373125, 2.65575), 23], [(1.0889375000000001, 2.65575), 6], [(0.6373125, 3.1392499999999997), 38], [(1.0889375000000001, 3.1392499999999997), 6], [(1.766375, 2.8975), 1], [(-1.1691875, 3.62275), 3], [(-0.7175625000000001, 3.62275), 17], [(-1.1691875, 4.106249999999999), 1], [(-0.7175625000000001, 4.106249999999999), 3], [(-0.26593750000000005, 3.62275), 27], [(0.18568749999999998, 3.62275), 26], [(-0.26593750000000005, 4.106249999999999), 8], [(0.18568749999999998, 4.106249999999999), 8], [(-0.04012500000000002, 4.8315), 3], [(0.6373125, 3.62275), 18], [(1.0889375000000001, 3.62275), 7], [(0.6373125, 4.106249999999999), 4], [(1.0889375000000001, 4.106249999999999), 1], [(2.669625, 5.7985), 1], [(3.572875, 5.7985), 4], [(2.669625, 6.765499999999999), 7], [(3.3470625, 6.52375), 5], [(3.7986874999999998, 6.52375), 14], [(3.3470625, 7.007249999999999), 11], [(3.68578125, 6.886374999999999), 9], [(3.9115937499999998, 6.886374999999999), 11], [(3.68578125, 7.128124999999999), 12], [(3.9115937499999998, 7.128124999999999), 15], [(4.476125, 5.7985), 12], [(5.379375, 5.7985), 1], [(4.2503125, 6.52375), 27], [(4.7019375, 6.52375), 13], [(4.13740625, 6.886374999999999), 16], [(4.36321875, 6.886374999999999), 11], [(4.13740625, 7.128124999999999), 21], [(4.36321875, 7.128124999999999), 21], [(4.58903125, 6.886374999999999), 16], [(4.81484375, 6.886374999999999), 7], [(4.58903125, 7.128124999999999), 14], [(4.81484375, 7.128124999999999), 8], [(5.379375, 6.765499999999999), 16], [(2.669625, 7.7325), 2], [(3.3470625, 7.49075), 15], [(3.7986874999999998, 7.49075), 39], [(3.3470625, 7.97425), 5], [(3.7986874999999998, 7.97425), 18], [(3.572875, 8.6995), 3], [(4.13740625, 7.369875), 14], [(4.36321875, 7.369875), 11], [(4.13740625, 7.611625), 17], [(4.36321875, 7.611625), 17], [(4.7019375, 7.49075), 32], [(4.2503125, 7.97425), 24], [(4.7019375, 7.97425), 12], [(5.379375, 7.7325), 13], [(4.476125, 8.6995), 6]] , of size: 78

# %% [markdown]
# # K means for blobs

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
y_kmeans = kmeans.fit_predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=5, cmap='bwr')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=300, alpha=1, marker='X')
plt.title('K-Means Clustering')
plt.grid(which='major')

x_ticks = [-1,2.5,6]
plt.xticks(x_ticks)

y_ticks = [2,5.5,9]
plt.yticks(y_ticks)
plt.show()

plt.show()
# Out:
# C:\Users\Stasius\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
silhouette_score = metrics.silhouette_score(X, y_kmeans)
inertia = kmeans.inertia_

print(f"Silhouette Score: {silhouette_score}") #how well-separated the clusters are
print(f"Inertia: {inertia}") # how far the points within a cluster are from the center of that cluster.
# Out:
# Silhouette Score: 0.8489182937774936
# Inertia: 505.15761447599994

# %% [markdown]
# # K means for coreset of blobs

# %%
coordinates = np.array([item[0] for item in S])
coreset_array = coordinates.reshape(-1, 2)
coreset_array[0:5]
# Out:
# array([[-0.943375 ,  1.9305   ],
#        [-0.2659375,  1.68875  ],
#        [-0.2659375,  2.17225  ],
#        [ 0.1856875,  2.17225  ],
#        [-1.1691875,  2.65575  ]])

# %%
corekmeans = KMeans(n_clusters=2, random_state=0)
y_corekmeans = corekmeans.fit_predict(coreset_array, sample_weight= [item[1] for item in S])

plt.scatter(coreset_array[:, 0], coreset_array[:, 1], c=y_corekmeans, s=10, cmap='bwr')
corecenters = corekmeans.cluster_centers_
plt.scatter(corecenters[:, 0], corecenters[:, 1], c='black', s=300, alpha=0.8, marker='X')
plt.title('K-Means Coreset Clustering')
plt.grid(which='major')

x_ticks = [-1,2.5,6]
plt.xticks(x_ticks)

y_ticks = [2,5.5,9]
plt.yticks(y_ticks)
plt.show()

plt.show()
# Out:
# C:\Users\Stasius\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
silhouette_score_core = metrics.silhouette_score(coreset_array, y_corekmeans)
inertia_core = corekmeans.inertia_

print(f"Silhouette Score: {silhouette_score_core}")
print(f"Inertia: {inertia_core}")
# Out:
# Silhouette Score: 0.778845282045127
# Inertia: 590.8146824697247

# %% [markdown]
# # Half circles (moons)

# %%
moons, moon_labels = sk.datasets.make_moons(n_samples=n, random_state=1, noise = 0.08)
moons = moons.round(3)
plt.scatter(moons[:, 0], moons[:, 1], c=moon_labels, cmap="bwr", s=8)
plt.grid(which='major');

# %%
S_moons = coreset_construction(moons, k, d, eps, len(moons));
# Out:
# The array is non-empty, proceeding with coreset construction algorithm
# delta = 6
# cs = 72
# Number of guesses for opt approximation = 94
#
# Iteration j = 0, with approximation Opt = (1+eps)^j = 1.0
#
# Threshold value: 0.09375 Points in cell: 1000
# Threshold value: 0.1875 Points in cell: 157
# Threshold value: 0.375 Points in cell: 0
# Threshold value: 0.375 Points in cell: 19
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 19
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 0.375 Points in cell: 41
# Threshold value: 0.75 Points in cell: 4
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 37
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.375 Points in cell: 97
# Threshold value: 0.75 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 48
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 12
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 16
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 10
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 31
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.1875 Points in cell: 334
# Threshold value: 0.375 Points in cell: 143
# Threshold value: 0.75 Points in cell: 14
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 10
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 34
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 14
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 7
# Threshold value: 12.0 Points in cell: 0
# Threshold value: 12.0 Points in cell: 1
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 12.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 58
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 20
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 10
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 16
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 37
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.375 Points in cell: 52
# Threshold value: 0.75 Points in cell: 4
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 45
# Threshold value: 1.5 Points in cell: 19
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 3
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.375 Points in cell: 40
# Threshold value: 0.75 Points in cell: 4
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 7
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 27
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.375 Points in cell: 99
# Threshold value: 0.75 Points in cell: 26
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 16
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 31
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 41
# Threshold value: 1.5 Points in cell: 19
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 12
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.1875 Points in cell: 329
# Threshold value: 0.375 Points in cell: 91
# Threshold value: 0.75 Points in cell: 35
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 14
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 0.75 Points in cell: 7
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 13
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 36
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 21
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.375 Points in cell: 44
# Threshold value: 0.75 Points in cell: 20
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 15
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 7
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.375 Points in cell: 53
# Threshold value: 0.75 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 50
# Threshold value: 1.5 Points in cell: 12
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.375 Points in cell: 141
# Threshold value: 0.75 Points in cell: 38
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 16
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 43
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 14
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 14
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 32
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 28
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.1875 Points in cell: 180
# Threshold value: 0.375 Points in cell: 95
# Threshold value: 0.75 Points in cell: 11
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 38
# Threshold value: 1.5 Points in cell: 18
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 20
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 38
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# ...
# Threshold value: 61.71717 Points in cell: 1
# Threshold value: 61.71717 Points in cell: 13
# Threshold value: 61.71717 Points in cell: 11
# Threshold value: 61.71717 Points in cell: 13
# Threshold value: 30.85858 Points in cell: 8
# Threshold value: 15.42929 Points in cell: 43
# Threshold value: 30.85858 Points in cell: 0
# Threshold value: 30.85858 Points in cell: 40
# Threshold value: 61.71717 Points in cell: 6
# Threshold value: 61.71717 Points in cell: 15
# Threshold value: 61.71717 Points in cell: 5
# Threshold value: 61.71717 Points in cell: 14
# Threshold value: 30.85858 Points in cell: 0
# Threshold value: 30.85858 Points in cell: 3
# Threshold value: 15.42929 Points in cell: 42
# Threshold value: 30.85858 Points in cell: 39
# Threshold value: 61.71717 Points in cell: 17
# Threshold value: 61.71717 Points in cell: 13
# Threshold value: 61.71717 Points in cell: 9
# Threshold value: 61.71717 Points in cell: 0
# Threshold value: 30.85858 Points in cell: 0
# Threshold value: 30.85858 Points in cell: 3
# Threshold value: 30.85858 Points in cell: 0
# Threshold value: 15.42929 Points in cell: 0
#
# Iteration j = 40, with approximation Opt = (1+eps)^j = 45.2592555681761
#
# Threshold value: 4.24306 Points in cell: 1000
# Threshold value: 8.48611 Points in cell: 157
# Threshold value: 16.97222 Points in cell: 0
# Threshold value: 16.97222 Points in cell: 19
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 19
# Threshold value: 16.97222 Points in cell: 41
# Threshold value: 33.94444 Points in cell: 4
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 37
# Threshold value: 67.88888 Points in cell: 9
# Threshold value: 67.88888 Points in cell: 8
# Threshold value: 67.88888 Points in cell: 5
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 16.97222 Points in cell: 97
# Threshold value: 33.94444 Points in cell: 2
# Threshold value: 33.94444 Points in cell: 48
# Threshold value: 67.88888 Points in cell: 13
# Threshold value: 67.88888 Points in cell: 12
# Threshold value: 67.88888 Points in cell: 18
# Threshold value: 67.88888 Points in cell: 5
# Threshold value: 33.94444 Points in cell: 16
# Threshold value: 33.94444 Points in cell: 31
# Threshold value: 8.48611 Points in cell: 334
# Threshold value: 16.97222 Points in cell: 143
# Threshold value: 33.94444 Points in cell: 14
# Threshold value: 33.94444 Points in cell: 34
# Threshold value: 67.88888 Points in cell: 1
# Threshold value: 67.88888 Points in cell: 1
# Threshold value: 67.88888 Points in cell: 14
# Threshold value: 67.88888 Points in cell: 18
# Threshold value: 33.94444 Points in cell: 58
# Threshold value: 67.88888 Points in cell: 18
# Threshold value: 67.88888 Points in cell: 20
# Threshold value: 67.88888 Points in cell: 16
# Threshold value: 67.88888 Points in cell: 4
# Threshold value: 33.94444 Points in cell: 37
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 67.88888 Points in cell: 2
# Threshold value: 67.88888 Points in cell: 5
# Threshold value: 16.97222 Points in cell: 52
# Threshold value: 33.94444 Points in cell: 4
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 45
# Threshold value: 67.88888 Points in cell: 19
# Threshold value: 67.88888 Points in cell: 2
# Threshold value: 67.88888 Points in cell: 9
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 33.94444 Points in cell: 3
# Threshold value: 16.97222 Points in cell: 40
# Threshold value: 33.94444 Points in cell: 4
# Threshold value: 33.94444 Points in cell: 7
# Threshold value: 33.94444 Points in cell: 2
# Threshold value: 33.94444 Points in cell: 27
# Threshold value: 16.97222 Points in cell: 99
# Threshold value: 33.94444 Points in cell: 26
# Threshold value: 33.94444 Points in cell: 31
# Threshold value: 33.94444 Points in cell: 1
# Threshold value: 33.94444 Points in cell: 41
# Threshold value: 67.88888 Points in cell: 19
# Threshold value: 67.88888 Points in cell: 4
# Threshold value: 67.88888 Points in cell: 12
# Threshold value: 67.88888 Points in cell: 6
# Threshold value: 8.48611 Points in cell: 329
# Threshold value: 16.97222 Points in cell: 91
# Threshold value: 33.94444 Points in cell: 35
# Threshold value: 67.88888 Points in cell: 4
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 67.88888 Points in cell: 2
# Threshold value: 67.88888 Points in cell: 14
# Threshold value: 33.94444 Points in cell: 7
# Threshold value: 33.94444 Points in cell: 13
# Threshold value: 33.94444 Points in cell: 36
# Threshold value: 67.88888 Points in cell: 11
# Threshold value: 67.88888 Points in cell: 1
# Threshold value: 67.88888 Points in cell: 21
# Threshold value: 67.88888 Points in cell: 3
# Threshold value: 16.97222 Points in cell: 44
# Threshold value: 33.94444 Points in cell: 20
# Threshold value: 33.94444 Points in cell: 15
# Threshold value: 33.94444 Points in cell: 7
# Threshold value: 33.94444 Points in cell: 2
# Threshold value: 16.97222 Points in cell: 53
# Threshold value: 33.94444 Points in cell: 1
# Threshold value: 33.94444 Points in cell: 50
# Threshold value: 67.88888 Points in cell: 12
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 67.88888 Points in cell: 8
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 2
# Threshold value: 16.97222 Points in cell: 141
# Threshold value: 33.94444 Points in cell: 38
# Threshold value: 67.88888 Points in cell: 4
# Threshold value: 67.88888 Points in cell: 3
# Threshold value: 67.88888 Points in cell: 16
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 33.94444 Points in cell: 43
# Threshold value: 67.88888 Points in cell: 2
# Threshold value: 67.88888 Points in cell: 13
# Threshold value: 67.88888 Points in cell: 14
# Threshold value: 67.88888 Points in cell: 14
# Threshold value: 33.94444 Points in cell: 32
# Threshold value: 33.94444 Points in cell: 28
# Threshold value: 8.48611 Points in cell: 180
# Threshold value: 16.97222 Points in cell: 95
# Threshold value: 33.94444 Points in cell: 11
# Threshold value: 33.94444 Points in cell: 38
# Threshold value: 67.88888 Points in cell: 18
# Threshold value: 67.88888 Points in cell: 0
# Threshold value: 67.88888 Points in cell: 20
# Threshold value: 67.88888 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 38
# Threshold value: 67.88888 Points in cell: 1
# Threshold value: 67.88888 Points in cell: 13
# Threshold value: 67.88888 Points in cell: 11
# Threshold value: 67.88888 Points in cell: 13
# Threshold value: 33.94444 Points in cell: 8
# Threshold value: 16.97222 Points in cell: 43
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 40
# Threshold value: 67.88888 Points in cell: 6
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 67.88888 Points in cell: 5
# Threshold value: 67.88888 Points in cell: 14
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 3
# Threshold value: 16.97222 Points in cell: 42
# Threshold value: 33.94444 Points in cell: 39
# Threshold value: 67.88888 Points in cell: 17
# Threshold value: 67.88888 Points in cell: 13
# Threshold value: 67.88888 Points in cell: 9
# Threshold value: 67.88888 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 3
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 16.97222 Points in cell: 0
#
# Iteration j = 41, with approximation Opt = (1+eps)^j = 49.78518112499371
#
# Threshold value: 4.66736 Points in cell: 1000
# Threshold value: 9.33472 Points in cell: 157
# Threshold value: 18.66944 Points in cell: 0
# Threshold value: 18.66944 Points in cell: 19
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 19
# Threshold value: 18.66944 Points in cell: 41
# Threshold value: 37.33889 Points in cell: 4
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 37
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 18.66944 Points in cell: 97
# Threshold value: 37.33889 Points in cell: 2
# Threshold value: 37.33889 Points in cell: 48
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 74.67777 Points in cell: 12
# Threshold value: 74.67777 Points in cell: 18
# Threshold value: 74.67777 Points in cell: 5
# Threshold value: 37.33889 Points in cell: 16
# Threshold value: 37.33889 Points in cell: 31
# Threshold value: 9.33472 Points in cell: 334
# Threshold value: 18.66944 Points in cell: 143
# Threshold value: 37.33889 Points in cell: 14
# Threshold value: 37.33889 Points in cell: 34
# Threshold value: 37.33889 Points in cell: 58
# Threshold value: 74.67777 Points in cell: 18
# Threshold value: 74.67777 Points in cell: 20
# Threshold value: 74.67777 Points in cell: 16
# Threshold value: 74.67777 Points in cell: 4
# Threshold value: 37.33889 Points in cell: 37
# Threshold value: 18.66944 Points in cell: 52
# Threshold value: 37.33889 Points in cell: 4
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 45
# Threshold value: 74.67777 Points in cell: 19
# Threshold value: 74.67777 Points in cell: 2
# Threshold value: 74.67777 Points in cell: 9
# Threshold value: 74.67777 Points in cell: 15
# Threshold value: 37.33889 Points in cell: 3
# Threshold value: 18.66944 Points in cell: 40
# Threshold value: 37.33889 Points in cell: 4
# Threshold value: 37.33889 Points in cell: 7
# Threshold value: 37.33889 Points in cell: 2
# Threshold value: 37.33889 Points in cell: 27
# Threshold value: 18.66944 Points in cell: 99
# Threshold value: 37.33889 Points in cell: 26
# Threshold value: 37.33889 Points in cell: 31
# Threshold value: 37.33889 Points in cell: 1
# Threshold value: 37.33889 Points in cell: 41
# Threshold value: 74.67777 Points in cell: 19
# Threshold value: 74.67777 Points in cell: 4
# Threshold value: 74.67777 Points in cell: 12
# Threshold value: 74.67777 Points in cell: 6
# Threshold value: 9.33472 Points in cell: 329
# Threshold value: 18.66944 Points in cell: 91
# Threshold value: 37.33889 Points in cell: 35
# Threshold value: 37.33889 Points in cell: 7
# Threshold value: 37.33889 Points in cell: 13
# Threshold value: 37.33889 Points in cell: 36
# Threshold value: 18.66944 Points in cell: 44
# Threshold value: 37.33889 Points in cell: 20
# Threshold value: 37.33889 Points in cell: 15
# Threshold value: 37.33889 Points in cell: 7
# Threshold value: 37.33889 Points in cell: 2
# Threshold value: 18.66944 Points in cell: 53
# Threshold value: 37.33889 Points in cell: 1
# Threshold value: 37.33889 Points in cell: 50
# Threshold value: 74.67777 Points in cell: 12
# Threshold value: 74.67777 Points in cell: 15
# Threshold value: 74.67777 Points in cell: 8
# Threshold value: 74.67777 Points in cell: 15
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 2
# Threshold value: 18.66944 Points in cell: 141
# Threshold value: 37.33889 Points in cell: 38
# Threshold value: 74.67777 Points in cell: 4
# Threshold value: 74.67777 Points in cell: 3
# Threshold value: 74.67777 Points in cell: 16
# Threshold value: 74.67777 Points in cell: 15
# Threshold value: 37.33889 Points in cell: 43
# Threshold value: 74.67777 Points in cell: 2
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 74.67777 Points in cell: 14
# Threshold value: 74.67777 Points in cell: 14
# Threshold value: 37.33889 Points in cell: 32
# Threshold value: 37.33889 Points in cell: 28
# Threshold value: 9.33472 Points in cell: 180
# Threshold value: 18.66944 Points in cell: 95
# Threshold value: 37.33889 Points in cell: 11
# Threshold value: 37.33889 Points in cell: 38
# Threshold value: 74.67777 Points in cell: 18
# Threshold value: 74.67777 Points in cell: 0
# Threshold value: 74.67777 Points in cell: 20
# Threshold value: 74.67777 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 38
# Threshold value: 74.67777 Points in cell: 1
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 74.67777 Points in cell: 11
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 37.33889 Points in cell: 8
# Threshold value: 18.66944 Points in cell: 43
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 40
# Threshold value: 74.67777 Points in cell: 6
# Threshold value: 74.67777 Points in cell: 15
# Threshold value: 74.67777 Points in cell: 5
# Threshold value: 74.67777 Points in cell: 14
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 3
# Threshold value: 18.66944 Points in cell: 42
# Threshold value: 37.33889 Points in cell: 39
# Threshold value: 74.67777 Points in cell: 17
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 74.67777 Points in cell: 9
# Threshold value: 74.67777 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 3
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 18.66944 Points in cell: 0
#
#  Coreset constructed:
#  [[(0.24837499999999996, -0.37887499999999996), 19], [(-1.027375, -0.13212499999999994), 4], [(-1.027375, 0.11462500000000005), 37], [(-0.176875, -0.13212499999999994), 2], [(0.14206249999999998, -0.19381249999999994), 13], [(0.35468749999999993, -0.19381249999999994), 12], [(0.14206249999999998, -0.07043749999999994), 18], [(0.35468749999999993, -0.07043749999999994), 5], [(-0.176875, 0.11462500000000005), 16], [(0.24837499999999996, 0.11462500000000005), 31], [(0.6736249999999999, -0.625625), 14], [(1.098875, -0.625625), 34], [(0.5673124999999999, -0.44056249999999997), 18], [(0.7799375, -0.44056249999999997), 20], [(0.5673124999999999, -0.31718749999999996), 16], [(0.7799375, -0.31718749999999996), 4], [(1.098875, -0.37887499999999996), 37], [(1.5241249999999997, -0.625625), 4], [(1.4178124999999997, -0.44056249999999997), 19], [(1.6304374999999998, -0.44056249999999997), 2], [(1.4178124999999997, -0.31718749999999996), 9], [(1.6304374999999998, -0.31718749999999996), 15], [(1.9493749999999999, -0.37887499999999996), 3], [(0.6736249999999999, -0.13212499999999994), 4], [(1.098875, -0.13212499999999994), 7], [(0.6736249999999999, 0.11462500000000005), 2], [(1.098875, 0.11462500000000005), 27], [(1.5241249999999997, -0.13212499999999994), 26], [(1.9493749999999999, -0.13212499999999994), 31], [(1.5241249999999997, 0.11462500000000005), 1], [(1.8430624999999998, 0.05293750000000005), 19], [(2.0556875, 0.05293750000000005), 4], [(1.8430624999999998, 0.17631250000000004), 12], [(2.0556875, 0.17631250000000004), 6], [(-1.027375, 0.361375), 35], [(-0.602125, 0.361375), 7], [(-1.027375, 0.608125), 13], [(-0.602125, 0.608125), 36], [(-0.176875, 0.361375), 20], [(0.24837499999999996, 0.361375), 15], [(-0.176875, 0.608125), 7], [(0.24837499999999996, 0.608125), 2], [(-1.027375, 0.854875), 1], [(-0.7084375, 0.7931875), 12], [(-0.4958125, 0.7931875), 15], [(-0.7084375, 0.9165625000000001), 8], [(-0.4958125, 0.9165625000000001), 15], [(-0.602125, 1.101625), 2], [(-0.28318750000000004, 0.7931875), 4], [(-0.07056250000000001, 0.7931875), 3], [(-0.28318750000000004, 0.9165625000000001), 16], [(-0.07056250000000001, 0.9165625000000001), 15], [(0.14206249999999998, 0.7931875), 2], [(0.35468749999999993, 0.7931875), 13], [(0.14206249999999998, 0.9165625000000001), 14], [(0.35468749999999993, 0.9165625000000001), 14], [(-0.176875, 1.101625), 32], [(0.24837499999999996, 1.101625), 28], [(0.6736249999999999, 0.361375), 11], [(0.9925625, 0.2996875), 18], [(0.9925625, 0.4230625), 20], [(0.5673124999999999, 0.5464375), 1], [(0.7799375, 0.5464375), 13], [(0.5673124999999999, 0.6698125), 11], [(0.7799375, 0.6698125), 13], [(1.098875, 0.608125), 8], [(1.8430624999999998, 0.2996875), 6], [(2.0556875, 0.2996875), 15], [(1.8430624999999998, 0.4230625), 5], [(2.0556875, 0.4230625), 14], [(1.9493749999999999, 0.608125), 3], [(0.5673124999999999, 0.7931875), 17], [(0.7799375, 0.7931875), 13], [(0.5673124999999999, 0.9165625000000001), 9], [(0.6736249999999999, 1.101625), 3]] , of size: 75
# No handles with labels found to put in legend.

# %% [markdown]
# # K means for moons

# %%
kmeans_moons = KMeans(n_clusters=2, random_state=0)
y_kmeans_moons = kmeans_moons.fit_predict(moons)

plt.scatter(moons[:, 0], moons[:, 1], c=y_kmeans_moons, s=5, cmap='bwr')
centers_moons = kmeans_moons.cluster_centers_
plt.scatter(centers_moons[:, 0], centers_moons[:, 1], c='black', s=300, alpha=0.8, marker='X')
plt.title('K-Means Clustering')
plt.grid(which='major')

x_ticks = [-1,0.5,2]
plt.xticks(x_ticks)

y_ticks = [-0.75,0.25,1]
plt.yticks(y_ticks)
plt.show()
# Out:
# C:\Users\Stasius\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
silhouette_score_moons = metrics.silhouette_score(moons, y_kmeans_moons)
inertia_moons = kmeans_moons.inertia_

print(f"Silhouette Score: {silhouette_score_moons}") #how well-separated the clusters are
print(f"Inertia: {inertia_moons}") # how far the points within a cluster are from the center of that cluster.
# Out:
# Silhouette Score: 0.49118118873967026
# Inertia: 404.38951595744743

# %% [markdown]
# # K means for coreset of moons

# %%
coordinates_moons = np.array([item[0] for item in S_moons])
coreset_array_moons = coordinates_moons.reshape(-1, 2)
coreset_array_moons[0:5]
# Out:
# array([[ 0.248375 , -0.378875 ],
#        [-1.027375 , -0.132125 ],
#        [-1.027375 ,  0.114625 ],
#        [-0.176875 , -0.132125 ],
#        [ 0.1420625, -0.1938125]])

# %%
corekmeans_moons = KMeans(n_clusters=2, random_state=0)
y_corekmeans_moons = corekmeans_moons.fit_predict(coreset_array_moons, sample_weight= [item[1] for item in S_moons])

plt.scatter(coreset_array_moons[:, 0], coreset_array_moons[:, 1], c=y_corekmeans_moons, s=10, cmap='bwr')
corecenters_moons = corekmeans_moons.cluster_centers_
plt.scatter(corecenters_moons[:, 0], corecenters_moons[:, 1], c='black', s=300, alpha=0.8, marker='X')
plt.title('K-Means Coreset Clustering')
plt.grid(which='major')

x_ticks = [-1,0.5,2]
plt.xticks(x_ticks)

y_ticks = [-0.75,0.25,1]
plt.yticks(y_ticks)
plt.show()
# Out:
# C:\Users\Stasius\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
silhouette_score_core_moons = metrics.silhouette_score(coreset_array_moons, y_corekmeans_moons)
inertia_core_moons = corekmeans_moons.inertia_

print(f"Silhouette Score: {silhouette_score_core_moons}") #how well-separated the clusters are
print(f"Inertia: {inertia_core_moons}") # how far the points within a cluster are from the center of that cluster.
# Out:
# Silhouette Score: 0.4474386204343666
# Inertia: 421.01385007487625

# %% [markdown]
# # Circles

# %%
circles, circles_labels = sk.datasets.make_circles(n_samples=n, random_state=1, noise = 0.07, factor=0.4)
circles = circles.round(3)
plt.scatter(circles[:, 0], circles[:, 1], c=circles_labels, cmap="bwr", s=8)
plt.grid(which='major');

# %%
S_circles = coreset_construction(circles, k, d, eps, len(circles));
# Out:
# The array is non-empty, proceeding with coreset construction algorithm
# delta = 6
# cs = 72
# Number of guesses for opt approximation = 94
#
# Iteration j = 0, with approximation Opt = (1+eps)^j = 1.0
#
# Threshold value: 0.09375 Points in cell: 1000
# Threshold value: 0.1875 Points in cell: 253
# Threshold value: 0.375 Points in cell: 25
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 3
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 4
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 18
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.375 Points in cell: 49
# Threshold value: 0.75 Points in cell: 19
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 10
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 22
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 8
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.375 Points in cell: 52
# Threshold value: 0.75 Points in cell: 22
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 8
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 21
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.375 Points in cell: 127
# Threshold value: 0.75 Points in cell: 6
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 43
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 20
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 64
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 1.5 Points in cell: 24
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 10
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 19
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 14
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.1875 Points in cell: 262
# Threshold value: 0.375 Points in cell: 53
# Threshold value: 0.75 Points in cell: 23
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 19
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 5
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 6
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.375 Points in cell: 30
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 28
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.375 Points in cell: 132
# Threshold value: 0.75 Points in cell: 59
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 25
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 21
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 10
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 15
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 48
# Threshold value: 1.5 Points in cell: 20
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 9
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 17
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.375 Points in cell: 47
# Threshold value: 0.75 Points in cell: 8
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 17
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 10
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 4
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 18
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.1875 Points in cell: 245
# Threshold value: 0.375 Points in cell: 51
# Threshold value: 0.75 Points in cell: 20
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 14
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 7
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 17
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 10
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.375 Points in cell: 123
# Threshold value: 0.75 Points in cell: 47
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 20
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 19
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 0.75 Points in cell: 18
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 14
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 10
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 10
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 48
# Threshold value: 1.5 Points in cell: 17
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 15
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.375 Points in cell: 26
# Threshold value: 0.75 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 22
# Threshold value: 1.5 Points in cell: 6
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 10
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 0.75 Points in cell: 0
# Threshold value: 0.75 Points in cell: 3
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.375 Points in cell: 45
# Threshold value: 0.75 Points in cell: 7
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 2
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 0.75 Points in cell: 14
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 8
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 22
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.1875 Points in cell: 240
# Threshold value: 0.375 Points in cell: 114
# Threshold value: 0.75 Points in cell: 18
# Threshold value: 1.5 Points in cell: 0
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 11
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 0.75 Points in cell: 40
# Threshold value: 1.5 Points in cell: 21
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 5
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 1
# Threshold value: 0.75 Points in cell: 46
# Threshold value: 1.5 Points in cell: 26
# Threshold value: 3.0 Points in cell: 8
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 3.0 Points in cell: 6
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 7
# Threshold value: 6.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 1.5 Points in cell: 13
# Threshold value: 3.0 Points in cell: 5
# Threshold value: 6.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 1.5 Points in cell: 3
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 1
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 1.5 Points in cell: 4
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 3.0 Points in cell: 0
# Threshold value: 0.75 Points in cell: 10
# Threshold value: 1.5 Points in cell: 9
# Threshold value: 3.0 Points in cell: 4
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 2
# Threshold value: 3.0 Points in cell: 3
# Threshold value: 6.0 Points in cell: 2
# Threshold value: 6.0 Points in cell: 0
# Threshold value: 6.0 Points in cell: 0
# ...
# Threshold value: 33.94444 Points in cell: 10
# Threshold value: 33.94444 Points in cell: 48
# Threshold value: 67.88888 Points in cell: 17
# Threshold value: 67.88888 Points in cell: 15
# Threshold value: 67.88888 Points in cell: 3
# Threshold value: 67.88888 Points in cell: 13
# Threshold value: 16.97222 Points in cell: 26
# Threshold value: 33.94444 Points in cell: 1
# Threshold value: 33.94444 Points in cell: 22
# Threshold value: 33.94444 Points in cell: 0
# Threshold value: 33.94444 Points in cell: 3
# Threshold value: 16.97222 Points in cell: 45
# Threshold value: 33.94444 Points in cell: 7
# Threshold value: 33.94444 Points in cell: 2
# Threshold value: 33.94444 Points in cell: 14
# Threshold value: 33.94444 Points in cell: 22
# Threshold value: 8.48611 Points in cell: 240
# Threshold value: 16.97222 Points in cell: 114
# Threshold value: 33.94444 Points in cell: 18
# Threshold value: 33.94444 Points in cell: 40
# Threshold value: 67.88888 Points in cell: 21
# Threshold value: 67.88888 Points in cell: 5
# Threshold value: 67.88888 Points in cell: 13
# Threshold value: 67.88888 Points in cell: 1
# Threshold value: 33.94444 Points in cell: 46
# Threshold value: 67.88888 Points in cell: 26
# Threshold value: 67.88888 Points in cell: 13
# Threshold value: 67.88888 Points in cell: 3
# Threshold value: 67.88888 Points in cell: 4
# Threshold value: 33.94444 Points in cell: 10
# Threshold value: 16.97222 Points in cell: 47
# Threshold value: 33.94444 Points in cell: 3
# Threshold value: 33.94444 Points in cell: 22
# Threshold value: 33.94444 Points in cell: 3
# Threshold value: 33.94444 Points in cell: 19
# Threshold value: 16.97222 Points in cell: 51
# Threshold value: 33.94444 Points in cell: 4
# Threshold value: 33.94444 Points in cell: 12
# Threshold value: 33.94444 Points in cell: 19
# Threshold value: 33.94444 Points in cell: 16
# Threshold value: 16.97222 Points in cell: 28
# Threshold value: 33.94444 Points in cell: 23
# Threshold value: 33.94444 Points in cell: 3
# Threshold value: 33.94444 Points in cell: 2
# Threshold value: 33.94444 Points in cell: 0
#
# Iteration j = 41, with approximation Opt = (1+eps)^j = 49.78518112499371
#
# Threshold value: 4.66736 Points in cell: 1000
# Threshold value: 9.33472 Points in cell: 253
# Threshold value: 18.66944 Points in cell: 25
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 3
# Threshold value: 37.33889 Points in cell: 4
# Threshold value: 37.33889 Points in cell: 18
# Threshold value: 18.66944 Points in cell: 49
# Threshold value: 37.33889 Points in cell: 19
# Threshold value: 37.33889 Points in cell: 22
# Threshold value: 37.33889 Points in cell: 8
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 18.66944 Points in cell: 52
# Threshold value: 37.33889 Points in cell: 22
# Threshold value: 37.33889 Points in cell: 8
# Threshold value: 37.33889 Points in cell: 21
# Threshold value: 37.33889 Points in cell: 1
# Threshold value: 18.66944 Points in cell: 127
# Threshold value: 37.33889 Points in cell: 6
# Threshold value: 37.33889 Points in cell: 43
# Threshold value: 74.67777 Points in cell: 5
# Threshold value: 74.67777 Points in cell: 5
# Threshold value: 74.67777 Points in cell: 20
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 37.33889 Points in cell: 64
# Threshold value: 74.67777 Points in cell: 8
# Threshold value: 74.67777 Points in cell: 24
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 74.67777 Points in cell: 19
# Threshold value: 37.33889 Points in cell: 14
# Threshold value: 9.33472 Points in cell: 262
# Threshold value: 18.66944 Points in cell: 53
# Threshold value: 37.33889 Points in cell: 23
# Threshold value: 37.33889 Points in cell: 19
# Threshold value: 37.33889 Points in cell: 5
# Threshold value: 37.33889 Points in cell: 6
# Threshold value: 18.66944 Points in cell: 30
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 28
# Threshold value: 37.33889 Points in cell: 2
# Threshold value: 18.66944 Points in cell: 132
# Threshold value: 37.33889 Points in cell: 59
# Threshold value: 74.67777 Points in cell: 9
# Threshold value: 74.67777 Points in cell: 4
# Threshold value: 74.67777 Points in cell: 25
# Threshold value: 74.67777 Points in cell: 21
# Threshold value: 37.33889 Points in cell: 10
# Threshold value: 37.33889 Points in cell: 15
# Threshold value: 37.33889 Points in cell: 48
# Threshold value: 74.67777 Points in cell: 20
# Threshold value: 74.67777 Points in cell: 3
# Threshold value: 74.67777 Points in cell: 17
# Threshold value: 74.67777 Points in cell: 8
# Threshold value: 18.66944 Points in cell: 47
# Threshold value: 37.33889 Points in cell: 8
# Threshold value: 37.33889 Points in cell: 17
# Threshold value: 37.33889 Points in cell: 4
# Threshold value: 37.33889 Points in cell: 18
# Threshold value: 9.33472 Points in cell: 245
# Threshold value: 18.66944 Points in cell: 51
# Threshold value: 37.33889 Points in cell: 20
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 14
# Threshold value: 37.33889 Points in cell: 17
# Threshold value: 18.66944 Points in cell: 123
# Threshold value: 37.33889 Points in cell: 47
# Threshold value: 74.67777 Points in cell: 3
# Threshold value: 74.67777 Points in cell: 20
# Threshold value: 74.67777 Points in cell: 5
# Threshold value: 74.67777 Points in cell: 19
# Threshold value: 37.33889 Points in cell: 18
# Threshold value: 37.33889 Points in cell: 10
# Threshold value: 37.33889 Points in cell: 48
# Threshold value: 74.67777 Points in cell: 17
# Threshold value: 74.67777 Points in cell: 15
# Threshold value: 74.67777 Points in cell: 3
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 18.66944 Points in cell: 26
# Threshold value: 37.33889 Points in cell: 1
# Threshold value: 37.33889 Points in cell: 22
# Threshold value: 37.33889 Points in cell: 0
# Threshold value: 37.33889 Points in cell: 3
# Threshold value: 18.66944 Points in cell: 45
# Threshold value: 37.33889 Points in cell: 7
# Threshold value: 37.33889 Points in cell: 2
# Threshold value: 37.33889 Points in cell: 14
# Threshold value: 37.33889 Points in cell: 22
# Threshold value: 9.33472 Points in cell: 240
# Threshold value: 18.66944 Points in cell: 114
# Threshold value: 37.33889 Points in cell: 18
# Threshold value: 37.33889 Points in cell: 40
# Threshold value: 74.67777 Points in cell: 21
# Threshold value: 74.67777 Points in cell: 5
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 74.67777 Points in cell: 1
# Threshold value: 37.33889 Points in cell: 46
# Threshold value: 74.67777 Points in cell: 26
# Threshold value: 74.67777 Points in cell: 13
# Threshold value: 74.67777 Points in cell: 3
# Threshold value: 74.67777 Points in cell: 4
# Threshold value: 37.33889 Points in cell: 10
# Threshold value: 18.66944 Points in cell: 47
# Threshold value: 37.33889 Points in cell: 3
# Threshold value: 37.33889 Points in cell: 22
# Threshold value: 37.33889 Points in cell: 3
# Threshold value: 37.33889 Points in cell: 19
# Threshold value: 18.66944 Points in cell: 51
# Threshold value: 37.33889 Points in cell: 4
# Threshold value: 37.33889 Points in cell: 12
# Threshold value: 37.33889 Points in cell: 19
# Threshold value: 37.33889 Points in cell: 16
# Threshold value: 18.66944 Points in cell: 28
# Threshold value: 37.33889 Points in cell: 23
# Threshold value: 37.33889 Points in cell: 3
# Threshold value: 37.33889 Points in cell: 2
# Threshold value: 37.33889 Points in cell: 0
#
# Iteration j = 42, with approximation Opt = (1+eps)^j = 54.763699237493086
#
# Threshold value: 5.1341 Points in cell: 1000
# Threshold value: 10.26819 Points in cell: 253
# Threshold value: 20.53639 Points in cell: 25
# Threshold value: 41.07277 Points in cell: 0
# Threshold value: 41.07277 Points in cell: 3
# Threshold value: 41.07277 Points in cell: 4
# Threshold value: 41.07277 Points in cell: 18
# Threshold value: 20.53639 Points in cell: 49
# Threshold value: 41.07277 Points in cell: 19
# Threshold value: 41.07277 Points in cell: 22
# Threshold value: 41.07277 Points in cell: 8
# Threshold value: 41.07277 Points in cell: 0
# Threshold value: 20.53639 Points in cell: 52
# Threshold value: 41.07277 Points in cell: 22
# Threshold value: 41.07277 Points in cell: 8
# Threshold value: 41.07277 Points in cell: 21
# Threshold value: 41.07277 Points in cell: 1
# Threshold value: 20.53639 Points in cell: 127
# Threshold value: 41.07277 Points in cell: 6
# Threshold value: 41.07277 Points in cell: 43
# Threshold value: 82.14555 Points in cell: 5
# Threshold value: 82.14555 Points in cell: 5
# Threshold value: 82.14555 Points in cell: 20
# Threshold value: 82.14555 Points in cell: 13
# Threshold value: 41.07277 Points in cell: 64
# Threshold value: 82.14555 Points in cell: 8
# Threshold value: 82.14555 Points in cell: 24
# Threshold value: 82.14555 Points in cell: 13
# Threshold value: 82.14555 Points in cell: 19
# Threshold value: 41.07277 Points in cell: 14
# Threshold value: 10.26819 Points in cell: 262
# Threshold value: 20.53639 Points in cell: 53
# Threshold value: 41.07277 Points in cell: 23
# Threshold value: 41.07277 Points in cell: 19
# Threshold value: 41.07277 Points in cell: 5
# Threshold value: 41.07277 Points in cell: 6
# Threshold value: 20.53639 Points in cell: 30
# Threshold value: 41.07277 Points in cell: 0
# Threshold value: 41.07277 Points in cell: 0
# Threshold value: 41.07277 Points in cell: 28
# Threshold value: 41.07277 Points in cell: 2
# Threshold value: 20.53639 Points in cell: 132
# Threshold value: 41.07277 Points in cell: 59
# Threshold value: 82.14555 Points in cell: 9
# Threshold value: 82.14555 Points in cell: 4
# Threshold value: 82.14555 Points in cell: 25
# Threshold value: 82.14555 Points in cell: 21
# Threshold value: 41.07277 Points in cell: 10
# Threshold value: 41.07277 Points in cell: 15
# Threshold value: 41.07277 Points in cell: 48
# Threshold value: 82.14555 Points in cell: 20
# Threshold value: 82.14555 Points in cell: 3
# Threshold value: 82.14555 Points in cell: 17
# Threshold value: 82.14555 Points in cell: 8
# Threshold value: 20.53639 Points in cell: 47
# Threshold value: 41.07277 Points in cell: 8
# Threshold value: 41.07277 Points in cell: 17
# Threshold value: 41.07277 Points in cell: 4
# Threshold value: 41.07277 Points in cell: 18
# Threshold value: 10.26819 Points in cell: 245
# Threshold value: 20.53639 Points in cell: 51
# Threshold value: 41.07277 Points in cell: 20
# Threshold value: 41.07277 Points in cell: 0
# Threshold value: 41.07277 Points in cell: 14
# Threshold value: 41.07277 Points in cell: 17
# Threshold value: 20.53639 Points in cell: 123
# Threshold value: 41.07277 Points in cell: 47
# Threshold value: 82.14555 Points in cell: 3
# Threshold value: 82.14555 Points in cell: 20
# Threshold value: 82.14555 Points in cell: 5
# Threshold value: 82.14555 Points in cell: 19
# Threshold value: 41.07277 Points in cell: 18
# Threshold value: 41.07277 Points in cell: 10
# Threshold value: 41.07277 Points in cell: 48
# Threshold value: 82.14555 Points in cell: 17
# Threshold value: 82.14555 Points in cell: 15
# Threshold value: 82.14555 Points in cell: 3
# Threshold value: 82.14555 Points in cell: 13
# Threshold value: 20.53639 Points in cell: 26
# Threshold value: 41.07277 Points in cell: 1
# Threshold value: 41.07277 Points in cell: 22
# Threshold value: 41.07277 Points in cell: 0
# Threshold value: 41.07277 Points in cell: 3
# Threshold value: 20.53639 Points in cell: 45
# Threshold value: 41.07277 Points in cell: 7
# Threshold value: 41.07277 Points in cell: 2
# Threshold value: 41.07277 Points in cell: 14
# Threshold value: 41.07277 Points in cell: 22
# Threshold value: 10.26819 Points in cell: 240
# Threshold value: 20.53639 Points in cell: 114
# Threshold value: 41.07277 Points in cell: 18
# Threshold value: 41.07277 Points in cell: 40
# Threshold value: 41.07277 Points in cell: 46
# Threshold value: 82.14555 Points in cell: 26
# Threshold value: 82.14555 Points in cell: 13
# Threshold value: 82.14555 Points in cell: 3
# Threshold value: 82.14555 Points in cell: 4
# Threshold value: 41.07277 Points in cell: 10
# Threshold value: 20.53639 Points in cell: 47
# Threshold value: 41.07277 Points in cell: 3
# Threshold value: 41.07277 Points in cell: 22
# Threshold value: 41.07277 Points in cell: 3
# Threshold value: 41.07277 Points in cell: 19
# Threshold value: 20.53639 Points in cell: 51
# Threshold value: 41.07277 Points in cell: 4
# Threshold value: 41.07277 Points in cell: 12
# Threshold value: 41.07277 Points in cell: 19
# Threshold value: 41.07277 Points in cell: 16
# Threshold value: 20.53639 Points in cell: 28
# Threshold value: 41.07277 Points in cell: 23
# Threshold value: 41.07277 Points in cell: 3
# Threshold value: 41.07277 Points in cell: 2
# Threshold value: 41.07277 Points in cell: 0
#
#  Coreset constructed:
#  [[(-0.7171874999999999, -0.9896875), 3], [(-1.0070625, -0.7030624999999999), 4], [(-0.7171874999999999, -0.7030624999999999), 18], [(-0.42731249999999993, -0.9896875), 19], [(-0.13743749999999993, -0.9896875), 22], [(-0.42731249999999993, -0.7030624999999999), 8], [(-1.0070625, -0.4164375), 22], [(-0.7171874999999999, -0.4164375), 8], [(-1.0070625, -0.12981250000000003), 21], [(-0.7171874999999999, -0.12981250000000003), 1], [(-0.42731249999999993, -0.4164375), 6], [(-0.20990624999999993, -0.48809375), 5], [(-0.06496874999999994, -0.48809375), 5], [(-0.20990624999999993, -0.34478125000000004), 20], [(-0.06496874999999994, -0.34478125000000004), 13], [(-0.49978124999999995, -0.20146875000000003), 8], [(-0.3548437499999999, -0.20146875000000003), 24], [(-0.49978124999999995, -0.058156250000000034), 13], [(-0.3548437499999999, -0.058156250000000034), 19], [(-0.13743749999999993, -0.12981250000000003), 14], [(0.15243750000000006, -0.9896875), 23], [(0.44231250000000005, -0.9896875), 19], [(0.15243750000000006, -0.7030624999999999), 5], [(0.44231250000000005, -0.7030624999999999), 6], [(0.7321875, -0.7030624999999999), 28], [(1.0220625, -0.7030624999999999), 2], [(0.07996875000000006, -0.48809375), 9], [(0.22490625000000006, -0.48809375), 4], [(0.07996875000000006, -0.34478125000000004), 25], [(0.22490625000000006, -0.34478125000000004), 21], [(0.44231250000000005, -0.4164375), 10], [(0.15243750000000006, -0.12981250000000003), 15], [(0.36984375, -0.20146875000000003), 20], [(0.5147812500000001, -0.20146875000000003), 3], [(0.36984375, -0.058156250000000034), 17], [(0.5147812500000001, -0.058156250000000034), 8], [(0.7321875, -0.4164375), 8], [(1.0220625, -0.4164375), 17], [(0.7321875, -0.12981250000000003), 4], [(1.0220625, -0.12981250000000003), 18], [(-1.0070625, 0.15681249999999994), 20], [(-1.0070625, 0.44343749999999993), 14], [(-0.7171874999999999, 0.44343749999999993), 17], [(-0.49978124999999995, 0.08515624999999995), 3], [(-0.3548437499999999, 0.08515624999999995), 20], [(-0.49978124999999995, 0.22846874999999994), 5], [(-0.3548437499999999, 0.22846874999999994), 19], [(-0.13743749999999993, 0.15681249999999994), 18], [(-0.42731249999999993, 0.44343749999999993), 10], [(-0.20990624999999993, 0.37178124999999995), 17], [(-0.06496874999999994, 0.37178124999999995), 15], [(-0.20990624999999993, 0.5150937499999999), 3], [(-0.06496874999999994, 0.5150937499999999), 13], [(-1.0070625, 0.7300624999999998), 1], [(-0.7171874999999999, 0.7300624999999998), 22], [(-0.7171874999999999, 1.0166875), 3], [(-0.42731249999999993, 0.7300624999999998), 7], [(-0.13743749999999993, 0.7300624999999998), 2], [(-0.42731249999999993, 1.0166875), 14], [(-0.13743749999999993, 1.0166875), 22], [(0.15243750000000006, 0.15681249999999994), 18], [(0.44231250000000005, 0.15681249999999994), 40], [(0.07996875000000006, 0.37178124999999995), 26], [(0.22490625000000006, 0.37178124999999995), 13], [(0.07996875000000006, 0.5150937499999999), 3], [(0.22490625000000006, 0.5150937499999999), 4], [(0.44231250000000005, 0.44343749999999993), 10], [(0.7321875, 0.15681249999999994), 3], [(1.0220625, 0.15681249999999994), 22], [(0.7321875, 0.44343749999999993), 3], [(1.0220625, 0.44343749999999993), 19], [(0.15243750000000006, 0.7300624999999998), 4], [(0.44231250000000005, 0.7300624999999998), 12], [(0.15243750000000006, 1.0166875), 19], [(0.44231250000000005, 1.0166875), 16], [(0.7321875, 0.7300624999999998), 23], [(1.0220625, 0.7300624999999998), 3], [(0.7321875, 1.0166875), 2]] , of size: 78

# %% [markdown]
# # K means for circles

# %%
kmeans_circles = KMeans(n_clusters=2, random_state=0)
y_kmeans_circles = kmeans_circles.fit_predict(circles)

plt.scatter(circles[:, 0], circles[:, 1], c=y_kmeans_circles, s=5, cmap='bwr')
centers_circles = kmeans_circles.cluster_centers_
plt.scatter(centers_circles[:, 0], centers_circles[:, 1], c='black', s=300, alpha=0.8, marker='X')
plt.title('K-Means Clustering')
plt.grid(which='major')

x_ticks = [-1,0,1]
plt.xticks(x_ticks)

y_ticks = [-1,0,1]
plt.yticks(y_ticks)

plt.show()
# Out:
# C:\Users\Stasius\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
silhouette_score_circles = metrics.silhouette_score(circles, y_kmeans_circles)
inertia_circles = kmeans_circles.inertia_

print(f"Silhouette Score: {silhouette_score_circles}") #how well-separated the clusters are
print(f"Inertia: {inertia_circles}") # how far the points within a cluster are from the center of that cluster.
# Out:
# Silhouette Score: 0.32911178578558076
# Inertia: 387.4881602338114

# %% [markdown]
# # K means for coreset of circles

# %%
coordinates_circles = np.array([item[0] for item in S_circles])
coreset_array_circles = coordinates_circles.reshape(-1, 2)
coreset_array_circles[0:5]
# Out:
# array([[-0.7171875, -0.9896875],
#        [-1.0070625, -0.7030625],
#        [-0.7171875, -0.7030625],
#        [-0.4273125, -0.9896875],
#        [-0.1374375, -0.9896875]])

# %%
corekmeans_circles = KMeans(n_clusters=2, random_state=0)
y_corekmeans_circles = corekmeans_circles.fit_predict(coreset_array_circles, sample_weight= [item[1] for item in S_circles])

plt.scatter(coreset_array_circles[:, 0], coreset_array_circles[:, 1], c=y_corekmeans_circles, s=10, cmap='bwr')
corecenters_circles = corekmeans_circles.cluster_centers_
plt.scatter(corecenters_circles[:, 0], corecenters_circles[:, 1], c='black', s=300, alpha=0.8, marker='X')
plt.title('K-Means Coreset Clustering')
plt.grid(which='major')

x_ticks = [-1,0,1]
plt.xticks(x_ticks)

y_ticks = [-1,0,1]
plt.yticks(y_ticks)

plt.show()
# Out:
# C:\Users\Stasius\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
silhouette_score_circles = metrics.silhouette_score(coreset_array_circles, y_corekmeans_circles)
inertia_circles = corekmeans_circles.inertia_

print(f"Silhouette Score: {silhouette_score_circles}") #how well-separated the clusters are
print(f"Inertia: {inertia_circles}") # how far the points within a cluster are from the center of that cluster.
# Out:
# Silhouette Score: 0.3143619172904558
# Inertia: 401.6038683610121

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))
axs = axs.ravel()
x_range = (-0.3, 0.9)

#blobs
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick', ax=axs[0],
                                  title=f"1. Blobs. Silhouette plot, KMeans n = {X.shape[0]}, k = {k}")
visualizer.fit(X)
visualizer.finalize()
axs[0].set_xlim(x_range)

#blobs core
visualizer = SilhouetteVisualizer(corekmeans, colors='yellowbrick', ax=axs[3],
                                  title=f"4. Blobs. Silhouette plot, KMeans cs = {coreset_array.shape[0]}, k = {k}")
visualizer.fit(coreset_array)
visualizer.finalize()
axs[3].set_xlim(x_range)

#moons
visualizer = SilhouetteVisualizer(kmeans_moons, colors='yellowbrick', ax=axs[1],
                                  title=f"2. Moons. Silhouette plot, KMeans n = {moons.shape[0]}, k = {k}")
visualizer.fit(moons)
visualizer.finalize()
axs[1].set_xlim(x_range)

#moons core
visualizer = SilhouetteVisualizer(corekmeans_moons, colors='yellowbrick', ax=axs[4],
                                  title=f"5. Moons. Silhouette plot, KMeans cs = {coreset_array_moons.shape[0]}, k = {k}")
visualizer.fit(coreset_array_moons)
visualizer.finalize()
axs[4].set_xlim(x_range)

#circles
visualizer = SilhouetteVisualizer(kmeans_moons, colors='yellowbrick', ax=axs[2],
                                  title=f"3. Circles. Silhouette plot, KMeans n = {circles.shape[0]}, k = {k}")
visualizer.fit(circles)
visualizer.finalize()
axs[2].set_xlim(x_range)

#circles core
visualizer = SilhouetteVisualizer(corekmeans_circles, colors='yellowbrick', ax=axs[5],
                                  title=f"6. Circles. Silhouette plot, KMeans cs = {coreset_array_circles.shape[0]}, k = {k}")
visualizer.fit(coreset_array_circles)
visualizer.finalize()
axs[5].set_xlim(x_range)

fig.suptitle(f'n = {n}', fontsize=14)
plt.tight_layout()
plt.show()
